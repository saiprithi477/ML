# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv(r'C:\Users\saiprithi\Documents\naresh it\datasience ai\xsel_sheets\winequality_red.csv')
x=df.drop('quality',axis=1)
y=df['quality']
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lasso_reg=Lasso(alpha=0.1)
lasso_reg.fit(x_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as  sns
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
# compute the correlation matrix
corr_matrix=df.corr()
print(corr_matrix)

# Visualization the correlation matrix
sns.heatmap(corr_matrix,annot=True, cmap='coolwarm')
plt.show()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
we will take one data set
we dwvided into tarin and test
we delveloped assume that 3 models
on train data
in that we picked 2 models
those 2 models performa on test data 

----train and test 
----- train and test & validation -->ask 

train error is low --validation is high test-->unseen data

sklearn.model train test split

train===>model===model====model---> 3 models

all the train data is used to develop the DT
all the train data is used to develop the KNN
all the train data is used to develop the NB
--------------
train data (750) is divided into 3 parts(250+250+250)
d1 is use to develop DT
D2 is used to develop KNN
D3 is used to develop NB

-- different samples mixing
-- different kind of ppl == DT KNN NB
ex:cricket
